# %%
# Open the lammps rdf file
with open('system_nvt1.rdf', 'r') as f:
    data1 = f.readlines()

# %%
# Open the lammps rdf file
with open('system_nvt05.rdf', 'r') as f:
    data05 = f.readlines()

# %%
# Open the lammps rdf file
with open('system_nvt01.rdf', 'r') as f:
    data01 = f.readlines()

# %%
# Open the lammps rdf file
with open('system_nvt005.rdf', 'r') as f:
    data005 = f.readlines()

# %%
# Open the lammps rdf file
with open('system_nvt001.rdf', 'r') as f:
    data001 = f.readlines()

# %%
# Open the lammps rdf file
with open('system_nvt0001.rdf', 'r') as f:
    data0001 = f.readlines()

# %%
# Read all the lines and get the x and y values
x1 = []
y1 = []
for l in data1[200:]:
    s = l.split()
    x1.append(float(s[1]))
    y1.append(float(s[2]))

# %%
# Read all the lines and get the x and y values
x05 = []
y05 = []
for l in data05[200:]:
    s = l.split()
    x05.append(float(s[1]))
    y05.append(float(s[2]))

# %%
# Read all the lines and get the x and y values
x01 = []
y01 = []
for l in data01[200:]:
    s = l.split()
    x01.append(float(s[1]))
    y01.append(float(s[2]))

# %%
# Read all the lines and get the x and y values
x005 = []
y005 = []
for l in data005[200:]:
    s = l.split()
    x005.append(float(s[1]))
    y005.append(float(s[2]))

# %%
# Read all the lines and get the x and y values
x001 = []
y001 = []
for l in data001[200:]:
    s = l.split()
    x001.append(float(s[1]))
    y001.append(float(s[2]))

# %%
# Read all the lines and get the x and y values
x0001 = []
y0001 = []
for l in data0001[200:]:
    s = l.split()
    x0001.append(float(s[1]))
    y0001.append(float(s[2]))

# %%
import matplotlib.pyplot as plt
width_in_inches = 15
height_in_inches = 8

plt.figure(figsize=(width_in_inches, height_in_inches))

plt.plot(x1, y1, 'r--', label="Eps = 1.0")
plt.plot(x05, y05, 'b--', label="Eps = 0.5")
plt.plot(x01, y01, label="Eps = 0.1")
plt.plot(x005, y005, label="Eps = 0.05")
plt.plot(x001, y001, 'g--', label="Eps = 0.01")
plt.plot(x0001, y0001, label="Eps = 0.001")
plt.legend()
plt.show()
